# %% [markdown]
# # ALL DATA VISUALIZATIONS IN SEABORN

# %% [markdown]
# <b> Importing the Libaries </b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <b> Importing the dataset </b>

# %%
df = pd.read_csv("D:\Data Science labs\Data for Practice\Titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <b> Information of data </b>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Checking for missin values

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Filling missing values with mean and mode

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Cabin'].fillna(df['Cabin'].mode()[0], inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             89
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Data Visualization plays a very important role in Data mining. Various data scientist spent their time exploring data through visualization. To accelerate this process we need to have a well-documentation of all the plots.
#
# Even plenty of resources can’t be transformed into valuable goods without planning and architecture. Therefore I hope this article would provide you a good architecture of all plots and their documentation.

# %% [markdown]
# * <b> 1.Distribution Plots </b>
#             a. Dist-plot
#             b. Joint Plot
#             c. Pair Plot
#             d. Rug Plot
#
# * <b> 2. Categorical Plots </b>
#             a. Bar Plot
#             b. Count Plot
#             c. Box Plot
#             d. Violin Plot
#
# * <b> 3. Advanced Plots </b>
#             a. Strip Plot
#             b. Swarm Plot
#
# * <b> 4.Matrix Plot </b>
#             a. Heat Map
#             b. Cluster Map
#
# * <b> 5. Grids </b>
#             a. Facet Grid
#
# * <b> 6. Regression Plots </b>

# %% [markdown]
# # Distribution Plots

# %% [markdown]
# <div class="alert alert-success">
# The distribution plot is suitable for comparing range and distribution for groups of numerical data. Data is plotted as value points along an axis.
#
# These plots help us to visualize the distribution of data. We can use these plots to understand the mean, median, range, variance, deviation, etc of the data. </div>

# %% [markdown]
# <b>a. Distplot </b>

# %% [markdown]
# * Dist plot gives us the histogram of the selected continuous variable.
#
# * It is an example of a `univariate analysis`.
#
# * We can change the number of bins i.e. number of vertical bars in a histogram.
#
# * `displot` is replaced with `histplot` , where subplots function works

# %% [markdown]
# > seaborn.histplot(data=None, *, x=None, y=None, hue=None, weights=None, stat='count', bins='auto', binwidth=None, binrange=None, discrete=None, cumulative=False, common_bins=True, common_norm=True, multiple='layer', element='bars', fill=True, shrink=1, kde=False, kde_kws=None, line_kws=None, thresh=0, pthresh=None, pmax=None, cbar=False, cbar_ax=None, cbar_kws=None, palette=None, hue_order=None, hue_norm=None, color=None, log_scale=None, legend=True, ax=None, **kwargs)

# %%
f,ax = plt.subplots(1,3,figsize=(16,5))
sns.histplot(x=df['Age'], bins = 10, ax=ax[0])
ax[0].set_title('displot of Age with bins = 10')

sns.histplot(x=df['Age'], bins = 15, edgecolor='black',ax=ax[1])
ax[1].set_title('displot of Age with bins = 15')

sns.histplot(x=df['Age'], kde=True,color='green', bins=15,ax=ax[2])
ax[2].set_title('displot with kde')

plt.show()

# %% [markdown]
# <b> b.Joint Point </b>

# %% [markdown]
# * It is the combination of the distplot of two variables.
# * It is an example of `bivariate analysis`.
# * We additionally obtain a scatter plot between the variable to reflecting their linear relationship. We can customize the scatter plot into a hexagonal plot, where, more the color intensity, the more will be the number of observations.

# %% [markdown]
# >seaborn.jointplot(data=None, *, x=None, y=None, hue=None, kind='scatter', height=6, ratio=5, space=0.2, dropna=False, xlim=None, ylim=None, color=None, palette=None, hue_order=None, hue_norm=None, marginal_ticks=False, joint_kws=None, marginal_kws=None, **kwargs)

# %%
#For plot1
sns.jointplot(x=df['Age'], y=df['Fare'], kind='scatter')

#For plot2
sns.jointplot(x=df['Age'], y=df['Fare'], kind='hex')

#For plot3
sns.jointplot(x=df['Age'], y=df['Fare'], kind='kde')

plt.show()

# %% [markdown]
# * We can see that there no appropriate linear relation between age and fare.
#
# * kind = ‘hex’ provides the hexagonal plot and kind = ‘reg’ provides a regression line on the graph.

# %% [markdown]
# <b> c.Pair plot </b>

# %% [markdown]
# * It takes all the numerical attributes of the data and plot pairwise scatter plot for two different variables and histograms from the same variables.

# %% [markdown]
# > seaborn.pairplot(data, *, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, corner=False, dropna=False, plot_kws=None, diag_kws=None, grid_kws=None, size=None)

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df, hue='Survived')
plt.show()

# %% [markdown]
# <b> d.Rug Plot </b>

# %% [markdown]
# * It draws a dash mark instead of a uniform distribution as in distplot.
#
# * It is an example of a univariate analysis.

# %% [markdown]
# > seaborn.rugplot(data=None, *, x=None,  y=None,  hue=None,  height=0.025,  expand_margins=True,  palette=None,  hue_order=None,  hue_norm=None,  legend=True,  ax=None,  **kwargs)

# %%
f,ax = plt.subplots(1,2,figsize=(16,5))
sns.rugplot(x=df['Age'], ax=ax[0])
ax[0].set_title('rugplot of Age')

sns.rugplot(x=df['Age'],color='green',ax=ax[1])
ax[1].set_title('rugplot of Age')

plt.show()

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# <div class='alert alert-success'>  These plots help us understand the categorical variables. We can use them for both univariate and bivariate analysis. </div>

# %% [markdown]
# <b> a.Bar Plot </b>

# %% [markdown]
# * It is an example of bivariate analysis.
# * On the x-axis, we have a `categorical variable` and on the y-axis, we have a `continuous variable`.

# %% [markdown]
# >  seaborn.barplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, estimator='mean', errorbar=('ci', 95), n_boot=1000, units=None, seed=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, errcolor='.26', errwidth=None, capsize=None, dodge=True, ci='deprecated', ax=None, **kwargs)

# %%
f,ax = plt.subplots(1,2,figsize=(16,5))
sns.barplot(x=df['Sex'], y=df['Fare'], ax=ax[0])
ax[0].set_title('Barplot of Sex and Age')

sns.barplot(x=df['SibSp'],y=df['Survived'], ax=ax[1])
ax[1].set_title('Barplot of SibSp and Survived')

plt.show()

# %% [markdown]
# <b> b. Count Plot </b>

# %% [markdown]
# * It counts the number of occurrences of categorical variables.
# * It is an example of a univariate analysis.

# %% [markdown]
# > seaborn.countplot(data=None, * , x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, ax=None, **kwargs)

# %%
f,ax = plt.subplots(1,2,figsize=(16,5))
sns.countplot(data=df, x="Pclass", hue="Survived",ax=ax[0])
ax[0].set_title('Countplot of Pclass and Survived')

sns.countplot(data=df,x='SibSp',hue='Survived', ax=ax[1])
ax[1].set_title('Countplot of SibSp and Survived')

plt.show()

# %% [markdown]
# <b> c.Box Plot </b>

# %% [markdown]
# * It is a `5 point summary plot`. It gives the information about the `maximum, minimum, mean, first quartile, and third quartile` of a continuous variable. Also, it equips us with knowledge of outliers.
# * We can plot this for a single continuous variable or can analyze different categorical variables based on a continuous variable.

# %% [markdown]
# > seaborn.boxplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)

# %%
f,ax = plt.subplots(1,2,figsize=(16,5))

sns.boxplot(y = df['Age'], x = df['Sex'],ax=ax[0])
ax[0].set_title('Box plot of Age and Sex')

sns.boxplot(df['Age'], ax=ax[1])
ax[1].set_title('Box plot of Age')

plt.show()

# %% [markdown]
# <b> d. Violin Plot </b>

# %% [markdown]
# * It is similar to the Box plot, but it gives supplementary information about the distribution too.

# %% [markdown]
# >seaborn.violinplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, bw='scott', cut=2, scale='area', scale_hue=True, gridsize=100, width=0.8, inner='box', split=False, dodge=True, orient=None, linewidth=None, color=None, palette=None, saturation=0.75, ax=None, **kwargs)

# %%
f,ax = plt.subplots(1,2,figsize=(16,5))

sns.violinplot(y = df['Age'], x = df['Sex'],ax=ax[0])
ax[0].set_title('Violin plot of Age and Sex')

sns.violinplot(data=df, x="Pclass", y="Age", hue="Survived", ax=ax[1])
ax[1].set_title('Violin plot of Age')

plt.show()

# %% [markdown]
# # <b> Advanced Plots </b>

# %% [markdown]
# <div class='alert alert-success'> As the name suggests, they are advanced because they ought to fuse the distribution and categorical encodings. </div>

# %% [markdown]
# <b> a. Strip Plot </b>

# %% [markdown]
# * It’s a plot between a `continuous variable` and a `categorical variable`.
# * It plots as a scatter plot but supplementarily uses categorical encodings of the categorical variable.

# %% [markdown]
# >seaborn.stripplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, jitter=True, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, hue_norm=None, native_scale=False, formatter=None, legend='auto', ax=None, **kwargs)

# %%
sns.stripplot(y = df['Age'], x = df['Pclass'])
plt.show()

# %% [markdown]
# * We can observe that in class 1 and class 2, children around 10 years are not present and the people having age above 60 are mostly accommodated in class 1.
#
# * Usually, these types of observations are used to impute missing values.

# %% [markdown]
# <b> b. Swarm Plot </b>

# %% [markdown]
# * It is the combination of a strip plot and a violin plot.
# * Along with the number of data points, it also provides their respective distribution.

# %% [markdown]
# >seaborn.swarmplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, hue_norm=None, native_scale=False, formatter=None, legend='auto', warn_thresh=0.05, ax=None, **kwargs)

# %%
sns.swarmplot(y = df['Age'], x = df['Pclass'])
plt.show()

# %% [markdown]
# # Matrix Plots

# %% [markdown]
# * These are the special types of plots that use `two-dimensional matrix` data for visualization. It is difficult to analyze and generate patterns from matrix data because of its large dimensions.
# * So, this makes the process easier by providing color coding to matrix data.

# %% [markdown]
# <b> a. Heat Map </b>

# %% [markdown]
# In the given raw dataset ‘df’, we have seven numeric variables. So, let us generate a correlation matrix between these seven variables.

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.091566
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# It seems very difficult to read every value even though there are only 49 values. The intricacy intensifies as we traverse towards thousands of features.
# So, let us try to implement some color coding and see how easy the interpretation becomes.

# %%
sns.heatmap(df.corr(), annot = True, cmap = 'viridis')
plt.show()

# %% [markdown]
# The same matrix is now articulating more information.
# Another very obvious example is to use heatmaps to understand the missing value patterns. In below figure, the yellow dash represents a missing value, if any? hence it makes our tasks more effortless to identify the missing values.

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# In the above data, no missing values, that's why everything is in same color.

# %% [markdown]
# <b> b. Cluster Map </b>

# %% [markdown]
# If we have a matrix data and want to group some features according to their similarity, cluster maps can assist us. Once, have a look at the heat map and then look at the cluster map.

# %% [markdown]
# > seaborn.clustermap(data, *, pivot_kws=None, method='average', metric='euclidean', z_score=None, standard_scale=None, figsize=(10, 10), cbar_kws=None, row_cluster=True, col_cluster=True, row_linkage=None, col_linkage=None, row_colors=None, col_colors=None, mask=None, dendrogram_ratio=0.2, colors_ratio=0.03, cbar_pos=(0.02, 0.8, 0.05, 0.18), tree_kws=None, **kwargs)

# %%
sns.clustermap(df.corr(),annot=True,cmap='viridis')
plt.show()

# %% [markdown]
# * The x-label and y-label are the same but they harmonized differently. That is because they are grouped according to their similarity.
# * The flow-chart like structure at the top and left describe their degree of similarity.
# * Cluster maps use `Hierarchical clustering` to form different clusters.

# %% [markdown]
# # Grids

# %% [markdown]
# Grid plots provide us more control over visualizations and plots various assorted graphs with a single line of code.

# %% [markdown]
# <b> a. Facet Grid </b>

# %% [markdown]
# * Suppose we want to plot the age distribution of males and females in all the three classes of tickets. Hence, we would be having in a total of 6 graphs.

# %%
sns.FacetGrid(df, col = 'Pclass', row = 'Sex').map(sns.distplot, 'Age')
plt.show()

# %% [markdown]
# * The Facet grids provide very clear graphs as per requirements.
# * sns.FacetGrid( col = ‘col’, row = ‘row’, data = data) provides an empty grid of all unique categories in the col and row. Later, we can use different plots and common variables for peculiar variations.

# %% [markdown]
# # Regression Plot

# %% [markdown]
# * This is a more advanced statistical plot that provides a scatter plot along with a linear fitting on the data.

# %%
sns.lmplot(x = 'Age', y = 'PassengerId', data = df, hue = 'Sex')
plt.show()

# %% [markdown]
# Fig displays the linear regression fitting between Passenger ID and Age for both males and females.
